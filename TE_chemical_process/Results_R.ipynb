# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
##### 定义图片上的字体
font = {'family': 'Times New Roman',
         'style': 'normal',
         'weight': 'bold',
        #'color':  'darkred', 
        'size': 20,
        }
matplotlib.rc('font', **font)

# %%
rRoot = "./data/r/r_0.11.txt"
R = np.loadtxt(rRoot)

# %%
y_attack_types = ['Normal', 'Fault 1', 'Fault 2', 'Fault 3', 'Fault 4', 
                'Fault 5', 'Fault 6', 'Fault 7', 'Fault 8', 'Fault 9', 'Fault 10', 'Fault 11', 'Fault 12','Fault 13', 
                'Fault 14', 'Fault 15', 'Fault 16', 'Fault 17', 'Fault 18', 'Fault 19', 'Fault 20', 'Fault 21']
x_attack_types = ["Attribute " + str(i) for i in range(1, 53)]

# %%
plt.figure(figsize=(22, 22))
y_tick_marks = np.arange(R.shape[0])
x_tick_marks = np.arange(R.shape[1])
plt.imshow(R, interpolation='nearest', cmap=plt.cm.Blues)
plt.xticks(x_tick_marks)
plt.yticks(y_tick_marks)
plt.tight_layout()
plt.ylabel('Categories')
plt.xlabel('Attributes')
plt.savefig("./results/r_0.11.svg")
